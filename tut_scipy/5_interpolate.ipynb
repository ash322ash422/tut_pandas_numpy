# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
import numpy as np

#lets generate data points whose curve we already know
x = np.linspace(0, 10, 10)
y = np.sin(x)
print(f"x:{x}")
print(f"y:{y}")

# Create interpolating function
f = interp1d(x, y, kind='cubic')

x_new = np.linspace(0, 10, 100)
y_new = f(x_new)

plt.plot(x, y, 'o', label='Data points')
plt.plot(x_new, y_new, '-', label='Cubic interpolation')
plt.legend()
plt.show()
# Out:
# x:[ 0.          1.11111111  2.22222222  3.33333333  4.44444444  5.55555556
#   6.66666667  7.77777778  8.88888889 10.        ]
# y:[ 0.          0.8961922   0.79522006 -0.19056796 -0.96431712 -0.66510151
#   0.37415123  0.99709789  0.51060568 -0.54402111]

# %% [markdown]
# ### perfect..it matches
